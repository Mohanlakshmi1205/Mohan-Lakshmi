# %%
import numpy as np 
import pandas as pd 

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
data=pd.read_csv(r"C:\Users\hp\Downloads\archive (19)\FDI Case Study.csv")
data.head(20)
# Out:
#                                 Complete View of Data Unnamed: 1 Unnamed: 2  \
# 0                                       Show  entries        NaN        NaN
# 1                                             Search:        NaN        NaN
# 2                                              Sector    2000-01    2001-02
# 3                            METALLURGICAL INDUSTRIES      22.69      14.14
# 4                                              MINING       1.32       6.52
# 5                                               POWER      89.42     757.44
# 6                             NON-CONVENTIONAL ENERGY          0          0
# 7                                     COAL PRODUCTION          0          0
# 8                             PETROLEUM & NATURAL GAS       9.35     211.07
# 9                 BOILERS AND STEAM GENERATING PLANTS          0          0
# 10     PRIME MOVER (OTHER THAN ELECTRICAL GENERATORS)          0          0
# ...

# %%
data.columns
# Out:
# Index(['Complete View of Data', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
#        'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17'],
#       dtype='object')

# %%
data.info
# Out:
# <bound method DataFrame.info of                                 Complete View of Data Unnamed: 1 Unnamed: 2  \
# 0                                       Show  entries        NaN        NaN
# 1                                             Search:        NaN        NaN
# 2                                              Sector    2000-01    2001-02
# 3                            METALLURGICAL INDUSTRIES      22.69      14.14
# 4                                              MINING       1.32       6.52
# ..                                                ...        ...        ...
# 79  11. Sectors that reported high decline in FDI ...        NaN        NaN
# 80        12. Which sectors has most varition in FDIs        NaN        NaN
# 81               13. Proportion of Each sector in FDI        NaN        NaN
# 82  14. are there some specific clusters that are ...        NaN        NaN
# 83             15. What is the forecast for next year        NaN        NaN
#
# ...

# %%
# Data Cleaning

data.drop([data.index[0],data.index[1]])
# Out:
#                                 Complete View of Data Unnamed: 1 Unnamed: 2  \
# 2                                              Sector    2000-01    2001-02
# 3                            METALLURGICAL INDUSTRIES      22.69      14.14
# 4                                              MINING       1.32       6.52
# 5                                               POWER      89.42     757.44
# 6                             NON-CONVENTIONAL ENERGY          0          0
# ..                                                ...        ...        ...
# 79  11. Sectors that reported high decline in FDI ...        NaN        NaN
# 80        12. Which sectors has most varition in FDIs        NaN        NaN
# 81               13. Proportion of Each sector in FDI        NaN        NaN
# 82  14. are there some specific clusters that are ...        NaN        NaN
# 83             15. What is the forecast for next year        NaN        NaN
#
# ...

# %%
data.dropna(how='any')
# Out:
#                                 Complete View of Data Unnamed: 1 Unnamed: 2  \
# 2                                              Sector    2000-01    2001-02
# 3                            METALLURGICAL INDUSTRIES      22.69      14.14
# 4                                              MINING       1.32       6.52
# 5                                               POWER      89.42     757.44
# 6                             NON-CONVENTIONAL ENERGY          0          0
# ..                                                ...        ...        ...
# 62                                               COIR          0          0
# 63           CONSTRUCTION (INFRASTRUCTURE) ACTIVITIES          0          0
# 64  CONSTRUCTION DEVELOPMENT: Townships, housing, ...      24.33      51.75
# 65                           MISCELLANEOUS INDUSTRIES     832.07     221.37
# 66                                        Grand Total    2378.68    4027.69
#
# ...

# %%
data.rename(columns={'Unnamed: 1':'Year','Unnamed: 2':'Year','Unnamed: 3':'Year','Unnamed: 4':'Year','Unnamed: 5':'Year',
                    'Unnamed: 6':'Year','Unnamed: 7':'Year','Unnamed: 8':'Year','Unnamed: 9':'Year','Unnamed: 10':'Year','Unnamed: 11':'Year',
                     'Unnamed: 12':'Year','Unnamed: 13':'Year','Unnamed: 14':'Year','Unnamed: 15':'Year','Unnamed: 16':'Year','Unnamed: 17':'Year'
                    },inplace=True)

# %%
from PIL import Image
pic1=Image.open(r'C:\Users\hp\Downloads\output1.png')
pic1
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=648x353 at 0x278CDFA48E0>

# %%
pic2=Image.open(r"C:\Users\hp\Downloads\output 2.png")
pic2
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=574x320 at 0x278D11BAD90>

# %%
pic3=Image.open(r"C:\Users\hp\Downloads\output 3.png")
pic3
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=959x508 at 0x278D11822B0>

# %%
pic4=Image.open(r"C:\Users\hp\Downloads\output 4.png")
pic4
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=502x506 at 0x278D15D4A90>

# %%
pic5=Image.open(r"C:\Users\hp\Downloads\output 5.png")
pic5
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=562x513 at 0x278D1568490>

# %%
pic6=Image.open(r"C:\Users\hp\Downloads\output 6.png")
pic6
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=955x482 at 0x278D11BADF0>

# %%
pic7=Image.open(r"C:\Users\hp\Downloads\output 7.png")
pic7
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=983x512 at 0x278D1568400>

# %%
pic8=Image.open(r"C:\Users\hp\Downloads\output 8.png")
pic8
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=966x510 at 0x278D10E07F0>
